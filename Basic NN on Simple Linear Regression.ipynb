# %% [markdown]
# # Basic Neural Network implemented on Simple Linear Regression

# %% [markdown]
# ### Import the relevant libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# ### Generate random input data for our model to train on

# %%
observations = 1000
xs = np.random.uniform(low=-10, high=10, size=(observations,1))
zs = np.random.uniform(-10, 10, (observations,1))
inputs = np.column_stack((xs,zs))

# %% [markdown]
# ### Generate the targets we will aim at

# %%
noise = np.random.uniform(-1, 1, (observations,1))
targets = 2*xs - 3*zs + 5 + noise

# %% [markdown]
# ### Plot the training data

# %%
#rehapre data for 3D plot
targets = targets.reshape(observations,)
xs = xs.reshape(observations,)
zs = zs.reshape(observations,)


fig = plt.figure()
#create the 3D plot
ax = fig.add_subplot(111, projection='3d')
ax.plot(xs, zs, targets)
ax.set_xlabel('xs')
ax.set_ylabel('zs')
ax.set_zlabel('Targets')
ax.view_init(azim=100)
plt.show()

#reshaping for futher analysis
targets = targets.reshape(observations,1)
xs = xs.reshape(observations,1)
zs = zs.reshape(observations,1)

# %% [markdown]
# ### Initialize variables

# %%
# initialize the weights and biases randomly in some small initial range.
init_range = 0.1
weights = np.random.uniform(low=-init_range, high=init_range, size=(2, 1))
biases = np.random.uniform(low=-init_range, high=init_range, size=1)

print (weights)
print (biases)
# Out:
# [[ 0.04190508]
#  [-0.0039144 ]]
# [0.03859331]

# %% [markdown]
# ### Set a learning rate

# %%
#choosen at random
learning_rate = 0.02

# %% [markdown]
# ### Train the model

# %%
for i in range (100):
    
    # This is the linear model: y = xw + b equation
    outputs = np.dot(inputs,weights) + biases

        
    # Using L2-norm loss, 
   .deltas = outputs - targets
    loss = np.sum(deltas ** 2) / 2 / observations
    print (loss)
    deltas_scaled = deltas / observations
    
    #using gradient descent update rules for the model to learn
    weights = weights - learning_rate * np.dot(inputs.T,deltas_scaled)
    biases = biases - learning_rate * np.sum(deltas_scaled)
# Out:
# 240.86417071705685
# 35.51193910187831
# 14.337143841054498
# 11.764187078018102
# 11.098597664913996
# 10.644404473613893
# 10.227338071168312
# 9.828787551499518
# 9.446230768292844
# 9.078845632023873
# 8.726011209133524
# 8.387149123105173
# 8.061705838523258
# 7.749149951163949
# 7.448971123499448
# 7.160679229724726
# 6.8838035530697965
# 6.617892016950676
# 6.362510446797475
# 6.117241861140059
# 5.88168579076934
# 5.655457624859839
# 5.43818798298548
# 5.229522112003284
# 5.02911930682013
# 4.836652354096933
# 4.651806997981789
# 4.4742814269998705
# 4.303785781262235
# 4.1400416791888786
# 3.982781762973369
# 3.831749262046834
# 3.686697573828558
# 3.5473898610786683
# 3.413598665195427
# 3.2851055348257874
# 3.1617006691827783
# 3.043182575487339
# 2.9293577399752957
# 2.820040311932307
# 2.7150518002408544
# 2.614220781943826
# 2.517382622348855
# 2.4243792062163654
# 2.3350586795924544
# 2.249275201865066
# 2.1668887076386008
# 2.0877646780381984
# 2.011773921070244
# ...

# %% [markdown]
# ### Print weights and biases and see if we have worked correctly.

# %%
# We print the weights and the biases, in order to test the models accuracy after 100 trys with our selected learning rate
print (weights, biases)
# Out:
# [[ 2.00018546]
#  [-3.00198808]] [4.34625117]
